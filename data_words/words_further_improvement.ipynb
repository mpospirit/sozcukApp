# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Words_Improved.csv')

# %%
df
# Out:
#           id        word                                         definition  \
# 0       7665        cerh                                           yaralama
# 1      18700      ilikçi                                   i̇lik açan kimse
# 2      15374       guano  özellikle deniz kuşlarının pisliklerinin bir y...
# 3      30349    mütemadi                                 sürekli, aralıksız
# 4       5253       benek  güneş lekeleri yöresinde görülen, parlak tanec...
# ...      ...         ...                                                ...
# 19242   3936  bakabilmek                bakma ihtimali veya imkânı bulunmak
# 19243   9347       değer  bir şeyin önemini belirlemeye yarayan soyut öl...
# 19244  38375     sıhhiye                              sağlık işlerinin tümü
# 19245  45081  yenebilmek                yenme ihtimali veya imkânı bulunmak
# 19246   1277   alımcılık                                       tahsildarlık
#
# ...

# %%
# values where ratio is greater than 30 and partial ratio is greater than 57
df = df[(df['ratio'] < 30) & (df['partial_ratio'] < 57)]

# %%
df
# Out:
#           id      word                                         definition  \
# 0       7665      cerh                                           yaralama
# 2      15374     guano  özellikle deniz kuşlarının pisliklerinin bir y...
# 3      30349  mütemadi                                 sürekli, aralıksız
# 4       5253     benek  güneş lekeleri yöresinde görülen, parlak tanec...
# 5      12524   estetik  güzelliği ve güzelliğin insan belleğindeki ve ...
# ...      ...       ...                                                ...
# 19237   7830      cima               i̇nsanlarda çiftleşme, cinsel ilişki
# 19238    190    acısız                                   tadı acı olmayan
# 19239  29076    minval                                   biçim, yol, tarz
# 19240  48203     çomak                                 ucu topuzlu değnek
# 19244  38375   sıhhiye                              sağlık işlerinin tümü
#
#        ratio  partial_ratio  token_sort_ratio  token_set_ratio  WRatio
# ...

# %%
14*365
# Out:
# 5110

# %%
df.to_csv('Words_Further_Improved.csv', index=False)
